# %%
import pandas as pd
import matplotlib.pyplot as plt

from data import MRIDataset

# %%
df = pd.read_csv('./data/cleaned_data.csv')
df
# Out:
#       Unnamed: 0    Patient_ID            Patient_Dir  \
# 0              0  TCGA_CS_4941  TCGA_CS_4941_19960909
# 1              1  TCGA_CS_4941  TCGA_CS_4941_19960909
# 2              2  TCGA_CS_4941  TCGA_CS_4941_19960909
# 3              3  TCGA_CS_4941  TCGA_CS_4941_19960909
# 4              4  TCGA_CS_4941  TCGA_CS_4941_19960909
# ...          ...           ...                    ...
# 3924        3924  TCGA_HT_A61B  TCGA_HT_A61B_19991127
# 3925        3925  TCGA_HT_A61B  TCGA_HT_A61B_19991127
# 3926        3926  TCGA_HT_A61B  TCGA_HT_A61B_19991127
# 3927        3927  TCGA_HT_A61B  TCGA_HT_A61B_19991127
# 3928        3928  TCGA_HT_A61B  TCGA_HT_A61B_19991127
#
#                                                     MRI  \
# 0     ./data/TCGA_CS_4941_19960909\TCGA_CS_4941_1996...
# 1     ./data/TCGA_CS_4941_19960909\TCGA_CS_4941_1996...
# 2     ./data/TCGA_CS_4941_19960909\TCGA_CS_4941_1996...
# 3     ./data/TCGA_CS_4941_19960909\TCGA_CS_4941_1996...
# ...

# %%
df.iloc[0]['MRI']
# Out:
# './data/TCGA_CS_4941_19960909\\TCGA_CS_4941_19960909_1.tif'

# %%
ds = MRIDataset(df)

# %%
mri = ds.__getitem__(2)['MRI']
mask = ds.__getitem__(2)['Mask']

# %%
plt.imshow(mri)

# %%
plt.imshow(mask)

# %%
print(2e-2)
# Out:
# 0.02
